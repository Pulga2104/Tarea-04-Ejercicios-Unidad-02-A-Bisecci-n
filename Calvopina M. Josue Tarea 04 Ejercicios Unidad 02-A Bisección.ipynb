# %% [markdown]
# ## [Tarea 04] Ejercicios Unidad 02-A | Bisección
#
# ### Nombre: Josue Steven Calvopiña Machuca
#
# ### Grupo: 1CC
#
# ### Fecha: 13/05/2026

# %% [markdown]
# 1. Use el método de bisección para encontrar soluciones precisas dentro de $10^{-2}$ para $x^3 - 7x^2 + 14x - 6 = 0$ en cada intervalo.
# a. $[0, 1]$
# b. $[1, 3.2]$
# c. $[3.2, 4]$

# %%
import math
from scipy.optimize import bisect


def f1(x):
    return x**3 - 7*x**2 + 14*x - 6


def ejercicio1():
    print("Ejercicio 1: f(x) = x^3 - 7x^2 + 14x - 6")

    intervalos = [(0, 1), (1, 3.2), (3.2, 4)]
    for a, b in intervalos:
        raiz = bisect(f1, a, b, xtol=1e-2)
        print(f"  Intervalo [{a}, {b}]  raíz = {raiz:.6f}")


ejercicio1()
# Out:
# Ejercicio 1: f(x) = x^3 - 7x^2 + 14x - 6
#   Intervalo [0, 1]  raíz = 0.585938
#   Intervalo [1, 3.2]  raíz = 3.002344
#   Intervalo [3.2, 4]  raíz = 3.418750

# %% [markdown]
# 2. a. Dibuje las gráficas para $y = x$ y $y = \sin x$.
#
#     b. Use el método de bisección para encontrar soluciones precisas dentro de $10^{-5}$ para el primer valor positivo de $x$ con $x = 2 \sin x$.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 4, 400)

y1 = x
y2 = np.sin(x)

plt.plot(x, y1, label="y = x", color="blue")
plt.plot(x, y2, label="y = sin(x)", color="red")

plt.title("Ejercicio 2 (a): Gráficas de y = x y y = sin(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()

plt.show()

# %%
import math
from scipy.optimize import bisect


def f2(x):
    return x - 2 * math.sin(x)


def ejercicio2():
    print("\nEjercicio 2: x = 2 sin(x)")
    raiz = bisect(f2, 1.5, 2, xtol=1e-5)
    print(f"Primera raíz positiva ≈ {raiz:.6f}")


ejercicio2()
# Out:
# Ejercicio 2: x = 2 sin(x)
# Primera raíz positiva ≈ 1.895500

# %% [markdown]
# 3. a. Dibuje las gráficas para $y = x$ y $y = \tan x$.
#
#     b. Use el método de bisección para encontrar una aproximación dentro de $10^{-5}$ para el primer valor positivo de $x$ con $x = \tan x$.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1, 4.5, 600)

y1 = x
y2 = np.tan(x)

plt.plot(x, y1, label="y = x", color="blue")
plt.plot(x, y2, label="y = tan(x)", color="red")

plt.ylim(-10, 10)
plt.title("Ejercicio 3 (a): Gráficas de y = x y y = tan(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()

plt.show()

# %%
import math
from scipy.optimize import bisect


def f2(x):
    return x - math.tan(x)


def ejercicio3():
    print("Ejercicio 3: x = tan(x)")
    raiz = bisect(f2, 1.5, 2, xtol=10e-5)
    print(f"Primera raiz positiva = {raiz:.6f}")


ejercicio3()
# Out:
# Ejercicio 3: x = tan(x)
# Primera raiz positiva = 1.570740

# %% [markdown]
# 4. a. Dibuje las gráficas para $y = x^2 - 1$ y $y = e^{1-x^2}$.
#
#     b. Use el método de bisección para encontrar una aproximación dentro de $10^{-3}$ para un valor en $[-2, 0]$ con $x^2 - 1 = e^{1-x^2}$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random

x = np.linspace(-3, 3, 400)

y1 = x - 1
y2 = np.exp(x)

x_rand = random.uniform(-3, 3)
x_ruido = x_rand + 0.0001234

p1 = x_ruido - 1
p2 = math.exp(x_ruido)

plt.plot(x, y1, label="y = x - 1", color="blue")
plt.plot(x, y2, label="y = e^x", color="red")

plt.scatter(x_ruido, p1, color="green",
            label=f"Punto en y=x-1 (x={x_ruido:.3f})")
plt.scatter(x_ruido, p2, color="orange",
            label=f"Punto en y=e^x (x={x_ruido:.3f})")

plt.title("Ejercicio 4 (a): Gráficas de y = x - 1 y y = e^x")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()

plt.show()

# %%
import math
from scipy.optimize import bisect


def f4(x):
    return x**2 - 1 - math.e**(1 - x**2)


def ejercicio4():
    print("\nEjercicio 4: x^2 - 1 = e^(1 - x^2)")
    raiz = bisect(f4, -1.5, -1.0, xtol=1e-3)
    print(f"Raíz ≈ {raiz:.6f}")


ejercicio4()
# Out:
# Ejercicio 4: x^2 - 1 = e^(1 - x^2)
# Raíz ≈ -1.250977

# %% [markdown]
# 5. Sea $f(x) = (x + 3)(x + 1)^2 x (x - 1)^3 (x - 3)$. ¿En qué cero de $f$ converge el método de bisección cuando se aplica en los siguientes intervalos?
# a. $[-1.5, 2.5]$
# b. $[-0.5, 2.4]$
# c. $[-0.5, 3]$
# d. $[-3, -0.5]$

# %%
import math
from scipy.optimize import bisect


def f5(x):
    return (x + 3)*(x + 1)**2 * x * (x - 1)**3 * (x - 3)


def ejercicio5():
    print("\nEjercicio 5: función con múltiples ceros")
    intervalos = [
        (-1.5, 2.5),
        (-0.5, 2.4),
        (-0.5, 3),
        (-3, -0.5)
    ]

    for a, b in intervalos:
        print(f"Intervalo [{a}, {b}]")
        try:
            raiz = bisect(f5, a, b, xtol=1e-6)
            print(f"Converge a raíz ≈ {raiz:.6f}")
        except ValueError:
            print("Bisección inválida")


ejercicio5()
# Out:
# Ejercicio 5: función con múltiples ceros
# Intervalo [-1.5, 2.5]
# Bisección inválida
# Intervalo [-0.5, 2.4]
# Bisección inválida
# Intervalo [-0.5, 3]
# Converge a raíz ≈ 3.000000
# Intervalo [-3, -0.5]
# Converge a raíz ≈ -3.000000

# %% [markdown]
# ## EJERCICIOS APLICADOS
#
# 1. Un abrevadero de longitud $L$ tiene una sección transversal en forma de semicírculo con radio $r$. Cuando se llena con agua hasta una distancia $h$ a partir de la parte superior, el volumen $V$ de agua es$$V = L \left[ 0.5\pi r^2 - r^2 \arcsin(h/r) - h(r^2 - h^2)^{1/2} \right]$$Suponga que $L = 10 \text{ cm}$, $r = 1 \text{ cm}$ y $V = 12.4 \text{ cm}^3$. Encuentre la profundidad del agua en el abrevadero dentro de $0.01 \text{ cm}$.

# %%
import math
from scipy.optimize import bisect


def volumen(h, L=10, r=1):
    return L * (0.5*math.pi*r**2 - r**2*math.asin(h/r) - h*math.sqrt(r**2 - h**2))


def g1(h):
    return volumen(h) - 12.4


def aplicado1():
    print("\nAplicado 1: abrevadero")
    raiz = bisect(g1, 0.1, 0.2, xtol=1e-6)
    profundidad = 2 - raiz
    print(f"h desde arriba ≈ {raiz:.4f} cm")
    print(f"Profundidad del agua ≈ {profundidad:.4f} cm")


aplicado1()
# Out:
# Aplicado 1: abrevadero
# h desde arriba ≈ 0.1662 cm
# Profundidad del agua ≈ 1.8338 cm

# %% [markdown]
# 2. Un objeto que cae verticalmente a través del aire está sujeto a una resistencia viscosa, así como a la fuerza de gravedad. Suponga que un objeto con masa 1$m$ cae desde una altura 2$s_0$ y que la altura del objeto después de 3$t$ segundos es4$$s(t) = s_0 - \frac{mg}{k}t + \frac{m^2g}{k^2} \left( 1 - e^{-kt/m} \right),$$donde $g = 9.81 \text{ m/s}^2$ y $k$ representa el coeficiente de la resistencia del aire en $\text{Ns/m}$. Suponga $s_0 = 300 \text{ m}$, $m = 0.25 \text{ kg}$ y $k = 0.1 \text{ Ns/m}$. Encuentre, dentro de $0.01 \text{ segundos}$, el tiempo que tarda un cuarto de kg en golpear el piso.

# %%
import math
from scipy.optimize import bisect


def s(t, s0=300, m=0.25, k=0.1, g=9.81):
    return s0 - (m*g/k)*t + (m**2 * g / k**2)*(1 - math.e**(-k*t/m))


def aplicado2():
    print("\nAplicado 2: caída con resistencia")
    raiz = bisect(s, 10, 20, xtol=0.01)
    print(f"Tiempo de caída ≈ {raiz:.2f} s")


aplicado2()
# Out:
# Aplicado 2: caída con resistencia
# Tiempo de caída ≈ 14.72 s

# %% [markdown]
# ## EJERCICIOS TEÓRICOS
#
# 1. Use el teorema 2.1 para encontrar una cota para el número de iteraciones necesarias para lograr una aproximación con precisión de $10^{-4}$ para la solución de $x^3 - x - 1 = 0$ que se encuentra dentro del intervalo $[1, 2]$. Encuentre una aproximación para la raíz con este grado de precisión.

# %%
import math
from scipy.optimize import bisect


def f_teo1(x):
    return x**3 - x - 1


def teorico1():
    print("\nTeórico 1: x^3 - x - 1")
    raiz = bisect(f_teo1, 1, 2, xtol=1e-4)
    print(f"Raíz ≈ {raiz:.6f}")


teorico1()
# Out:
# Teórico 1: x^3 - x - 1
# Raíz ≈ 1.324768

# %% [markdown]
# 2. La función definida por $f(x) = \sin \pi x$ tiene ceros en cada entero. Muestre cuando $-1 < a < 0$ y $2 < b < 3$, el método de bisección converge a
# a. $0, \text{si } a + b < 2$
# b. $2, \text{si } a + b > 2$
# c. 1$1, \text{si } a + b = 2$
#
# La respuesta correcta es:
#
# - Si $a + b < 2$, el método de bisección converge a la raíz $x = 0$.
#
# - Si $a + b > 2$, converge a la raíz $x = 2$.
#
# - Si $a + b = 2$, converge directamente a la raíz $x = 1$, siendo este último caso el más eficiente porque encuentra la solución en un solo paso.
